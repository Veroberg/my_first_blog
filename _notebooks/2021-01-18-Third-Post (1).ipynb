# %% [markdown]
# # My page
# > Criando a minha primeira página de Blog com o Jupyter Notebook
# - toc: false
# - branch: master
# - badges: false
# - comments: false
# - author: Veronica
# - categories: [blog]

# %%
import pandas as pd
import numpy as np

# %%
data = np.random.randint(0,800,(3,3))
data
# Out:
# array([[182, 362, 529],
#        [359, 668, 654],
#        [ 49, 424, 109]])

# %%
df1 = pd.DataFrame(data)
df1
# Out:
#      0    1    2
# 0  182  362  529
# 1  359  668  654
# 2   49  424  109

# %%
#hide_input
df2 = pd.DataFrame(data)
df2
# Out:
#      0    1    2
# 0  182  362  529
# 1  359  668  654
# 2   49  424  109

# %%
#hide
df3 = pd.DataFrame(data)
df3
# Out:
#      0    1    2
# 0  182  362  529
# 1  359  668  654
# 2   49  424  109
