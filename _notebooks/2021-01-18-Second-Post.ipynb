# %% [markdown]
# My page
#
# Criando a minha primeira página de Blog com o Jupyter Notebook
#
# toc: false
# branch: master
# badges: false
# comments: false
# author: Veronica
# categories: [blog]

# %%
import pandas as pd
import numpy as np

# %%
data = np.random.randint(0,500,(5,5))
data
# Out:
# array([[226, 205, 437, 484, 140],
#        [119, 278, 246, 287, 411],
#        [ 49, 293, 159, 395, 182],
#        [233, 258, 161, 429, 200],
#        [110, 334, 137, 431, 328]])

# %%
df1 = pd.DataFrame(data)
df1
# Out:
#      0    1    2    3    4
# 0  226  205  437  484  140
# 1  119  278  246  287  411
# 2   49  293  159  395  182
# 3  233  258  161  429  200
# 4  110  334  137  431  328

# %%
#hide_input
df2 = pd.DataFrame(data)
df2
# Out:
#      0    1    2    3    4
# 0  226  205  437  484  140
# 1  119  278  246  287  411
# 2   49  293  159  395  182
# 3  233  258  161  429  200
# 4  110  334  137  431  328

# %%
#hide
df3 = pd.DataFrame(data)
df3
# Out:
#      0    1    2    3    4
# 0  226  205  437  484  140
# 1  119  278  246  287  411
# 2   49  293  159  395  182
# 3  233  258  161  429  200
# 4  110  334  137  431  328
