# %% [markdown]
# My page
#
# Criando a minha primeira página de Blog com o Jupyter Notebook
#
# - toc: false
# - branch: master
# - badges: false
# - comments: false
# - author: Veronica
# - categories: [blog]

# %%
import pandas as pd
import numpy as np

# %%
data = np.random.randint(0,500,(5,5))
data
# Out:
# array([[429, 411, 285, 182, 237],
#        [254,  84, 180,  36, 410],
#        [245, 415, 418, 133, 295],
#        [ 34,  60, 439, 240, 366],
#        [418, 289, 390, 456, 462]])

# %%
df1 = pd.DataFrame(data)
df1
# Out:
#      0    1    2    3    4
# 0  429  411  285  182  237
# 1  254   84  180   36  410
# 2  245  415  418  133  295
# 3   34   60  439  240  366
# 4  418  289  390  456  462

# %%
#hide_input
df2 = pd.DataFrame(data)
df2
# Out:
#      0    1    2    3    4
# 0  429  411  285  182  237
# 1  254   84  180   36  410
# 2  245  415  418  133  295
# 3   34   60  439  240  366
# 4  418  289  390  456  462

# %%
#hide
df3 = pd.DataFrame(data)
df3
# Out:
#      0    1    2    3    4
# 0  429  411  285  182  237
# 1  254   84  180   36  410
# 2  245  415  418  133  295
# 3   34   60  439  240  366
# 4  418  289  390  456  462
