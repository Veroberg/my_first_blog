# %% [markdown]
# # My page
# > Criando a minha primeira página de Blog com o Jupyter Notebook
# - toc: false
# - branch: master
# - badges: false
# - comments: false
# - author: Veronica
# - categories: [blog]

# %%
import pandas as pd
import numpy as np

# %%
data = np.random.randint(0,5000,(6,4))
data
# Out:
# array([[2257, 2779,  403, 4266],
#        [4371, 3054, 1253, 2118],
#        [2623, 1321, 1808, 1794],
#        [ 304,  431, 4785, 3127],
#        [3754, 4798, 1714,  794],
#        [  22, 1275, 3288, 1232]])

# %%
Cc1 = pd.DataFrame(data)
Cc1
# Out:
#       0     1     2     3
# 0  2257  2779   403  4266
# 1  4371  3054  1253  2118
# 2  2623  1321  1808  1794
# 3   304   431  4785  3127
# 4  3754  4798  1714   794
# 5    22  1275  3288  1232

# %%
#hide_input Cc2 = pd.DataFrame(data)
#Cc2

# %%
#hide Cc3 = pd.DataFrame(data)
Cc3
# Out:
#       0     1     2     3
# 0  2257  2779   403  4266
# 1  4371  3054  1253  2118
# 2  2623  1321  1808  1794
# 3   304   431  4785  3127
# 4  3754  4798  1714   794
# 5    22  1275  3288  1232
