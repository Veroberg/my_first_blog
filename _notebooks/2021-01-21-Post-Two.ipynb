# %% [markdown]
# # My page
# > Criando a minha primeira página de Blog com o Jupyter Notebook
# - toc: false
# - branch: master
# - badges: false
# - comments: false
# - author: Veronica
# - categories: [blog]

# %%
import pandas as pd
import numpy as np

# %%
data = np.random.randint(0,500,(5,5))
data
# Out:
# array([[ 95, 298, 205,  11,  98],
#        [461, 398, 282, 454,  96],
#        [204, 207,  20, 341, 288],
#        [367, 142, 492,  80,  75],
#        [189, 242, 298, 382,  90]])

# %%
Cb1 = pd.DataFrame(data)
Cb1
# Out:
#      0    1    2    3    4
# 0   95  298  205   11   98
# 1  461  398  282  454   96
# 2  204  207   20  341  288
# 3  367  142  492   80   75
# 4  189  242  298  382   90

# %%
#hide_input Cb2 = pd.DataFrame(data)
Cb2
# Out:
#      0    1    2    3    4
# 0   95  298  205   11   98
# 1  461  398  282  454   96
# 2  204  207   20  341  288
# 3  367  142  492   80   75
# 4  189  242  298  382   90

# %%
#hide Cb3 = pd.DataFrame(data)
Cb3
# Out:
#      0    1    2    3    4
# 0   95  298  205   11   98
# 1  461  398  282  454   96
# 2  204  207   20  341  288
# 3  367  142  492   80   75
# 4  189  242  298  382   90
