# %% [markdown]
# # My page
# > Criando a minha primeira página de Blog com o Jupyter Notebook
# - toc: false
# - branch: master
# - badges: false
# - comments: false
# - author: Veronica
# - categories: [blog]

# %%
import pandas as pd
import numpy as np

# %%
data = np.random.randint(0,500,(5,5))
data
# Out:
# array([[400, 134, 169, 172, 101],
#        [478, 485, 301, 134, 249],
#        [151, 256, 407, 465,  99],
#        [139,  65, 357, 206, 499],
#        [138, 127, 369, 140, 227]])

# %%
Cb1 = pd.DataFrame(data)
Cb1
# Out:
#      0    1    2    3    4
# 0  400  134  169  172  101
# 1  478  485  301  134  249
# 2  151  256  407  465   99
# 3  139   65  357  206  499
# 4  138  127  369  140  227

# %%
#hide_input
Cb2 = pd.DataFrame(data)
Cb2
# Out:
#      0    1    2    3    4
# 0  400  134  169  172  101
# 1  478  485  301  134  249
# 2  151  256  407  465   99
# 3  139   65  357  206  499
# 4  138  127  369  140  227

# %%
#hide
Cb3 = pd.DataFrame(data)
Cb3
# Out:
#      0    1    2    3    4
# 0  400  134  169  172  101
# 1  478  485  301  134  249
# 2  151  256  407  465   99
# 3  139   65  357  206  499
# 4  138  127  369  140  227
