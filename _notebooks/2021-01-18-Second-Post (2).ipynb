# %% [markdown]
# # My page
# > Criando a minha primeira página de Blog com o Jupyter Notebook
# - toc: false
# - branch: master
# - badges: false
# - comments: false
# - author: Veronica
# - categories: [blog]

# %%
import pandas as pd
import numpy as np

# %%
data = np.random.randint(0,500,(5,5))
data
# Out:
# array([[331,  69, 328, 108, 489],
#        [315, 321,  32, 245, 493],
#        [256, 346, 353, 261, 368],
#        [ 43,  54, 196, 136, 496],
#        [ 30, 197, 189, 243, 301]])

# %%
df1 = pd.DataFrame(data)
df1
# Out:
#      0    1    2    3    4
# 0  331   69  328  108  489
# 1  315  321   32  245  493
# 2  256  346  353  261  368
# 3   43   54  196  136  496
# 4   30  197  189  243  301

# %%
#hide_input
df2 = pd.DataFrame(data)
df2
# Out:
#      0    1    2    3    4
# 0  331   69  328  108  489
# 1  315  321   32  245  493
# 2  256  346  353  261  368
# 3   43   54  196  136  496
# 4   30  197  189  243  301

# %%
#hide#hide_input
df3 = pd.DataFrame(data)
df3
# Out:
#      0    1    2    3    4
# 0  331   69  328  108  489
# 1  315  321   32  245  493
# 2  256  346  353  261  368
# 3   43   54  196  136  496
# 4   30  197  189  243  301
