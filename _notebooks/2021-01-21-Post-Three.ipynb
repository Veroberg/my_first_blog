# %% [markdown]
# # My page
# > Criando a minha primeira página de Blog com o Jupyter Notebook
# - toc: false
# - branch: master
# - badges: false
# - comments: false
# - author: Veronica
# - categories: [blog]

# %%
import pandas as pd
import numpy as np

# %%
data = np.random.randint(0,800,(3,3))
data
# Out:
# array([[442, 100, 198],
#        [664, 201, 719],
#        [197, 424, 445]])

# %%
Cc1 = pd.DataFrame(data)
Cc1
# Out:
#      0    1    2
# 0  442  100  198
# 1  664  201  719
# 2  197  424  445

# %%
#hide_input
Cc2 = pd.DataFrame(data)
Cc2
# Out:
#      0    1    2
# 0  442  100  198
# 1  664  201  719
# 2  197  424  445

# %%
#hide
Cc3 = pd.DataFrame(data)
Cc3
# Out:
#      0    1    2
# 0  442  100  198
# 1  664  201  719
# 2  197  424  445
