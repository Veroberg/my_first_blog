# %% [markdown]
# # My page
# > Criando a minha primeira página de Blog com o Jupyter Notebook
# - toc: false
# - branch: master
# - badges: false
# - comments: false
# - author: Veronica
# - categories: [blog]

# %%
import pandas as pd
import numpy as np

# %%
data = np.random.randint(0,500,(5,5))
data
# Out:
# array([[ 56,  37,  50, 405, 341],
#        [258, 448, 202,  29, 392],
#        [213,  38, 177, 377,  10],
#        [ 22,  86, 223, 421, 311],
#        [455, 495,  81,  25, 404]])

# %%
df1 = pd.DataFrame(data)
df1
# Out:
#      0    1    2    3    4
# 0   56   37   50  405  341
# 1  258  448  202   29  392
# 2  213   38  177  377   10
# 3   22   86  223  421  311
# 4  455  495   81   25  404

# %%
#hide_input
df2 = pd.DataFrame(data)
df2
# Out:
#      0    1    2    3    4
# 0   56   37   50  405  341
# 1  258  448  202   29  392
# 2  213   38  177  377   10
# 3   22   86  223  421  311
# 4  455  495   81   25  404

# %%
#hide
df3 = pd.DataFrame(data)
df3
# Out:
#      0    1    2    3    4
# 0   56   37   50  405  341
# 1  258  448  202   29  392
# 2  213   38  177  377   10
# 3   22   86  223  421  311
# 4  455  495   81   25  404
